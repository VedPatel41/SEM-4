# %% [markdown]
# # JSX RUles
# - Return Single Root Element
# - Close All tags
# - Use camelCase Attribute
# - Passing JS Expression
# - JSX Styling
# - JSX Comments

# %% [markdown]
# # 1
#     <h1>Hello</h1>
#     <p>Hiee</p>

# %% [markdown]
# # 2
# ```
#         <img src="1.png">
#         <li>Hello</li>
# ```

# %% [markdown]
# # 3
# ```<h1 className='abc'>
# fontSize,backgroundColor
#
# ```

# %% [markdown]
# # 4
# ```
#
# ```

# %% [markdown]
# # 5
# ```
#    <h2 style={{color:'red',fontSize:250}}>
# ```

# %% [markdown]
# npm run dev -- --port 3000

# %% [markdown]
# npm run dev
